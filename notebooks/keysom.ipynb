# %% [markdown]
# # AMADS Coding Notebooks
#
# ### Self-Organizing Maps (SOM) and Applications in AMADS
#
# This notebook intends to serve as a gentle introduction to self-organizing maps,
# and its primary use-case in AMADS.
#
# ---
#
# **For:** Attached to the
# [AMADS code library](https://github.com/music-computing/amads/) and
# ["Keeping Score" book](https://doi.org/10.5281/zenodo.14938027),
# but open to all.
#
# **Licence:** MIT.
#
# **Colour key:**
# - <font color='green'> Green is for a block of information.
# - <font color='purple'> Purple is for an exercise.
# - <font color='crimson'> Crimson is for the solution to the exercise above it.

# %%
## <font color='Green'> What are self-organizing maps?

# %%
What are our main goals for providing this notebook?
In other words, what do we hope students get to learn from reading this notebook?
Let's write a list of priorities:
(0) Roughly know how to use the KeySOM module in AMADS and relevant facilities.
(0.0) We should probably provide a simple toy example of how it's used.
(0.1) Provide a simple toy example of what I should do.
(1) Provide the absolute fundamentals of SOMs, and a light expose on
what SOMs are generally used for?
(1.0) Formulation, how it's trained
(1.1) Some immediate consequences and applications
(2) How are they used in this notebook? (seriously though, how can I have the
stomach to present something that I don't feel comfortable with myself...)
(2.0) Leverage key profiles
(3) Some examples for this notebook.
(3.0)

# %%
To not scare people off.
(1) Gentle description (provide intuition)
Self-organizing maps (SOM) are basically a collection of feature elements that
are used to learn the map.

How would I write this out? There really isn't that much to write?

I guess, I should go back to my notes... What questions did I ask when I
first learned this.

(2) Formal formulation
According to wikipedia, self-organizing maps are an unsupervised machine
learning technique that produces a low-dimensional representation of
higher-dimensional data while preserving the topological structure of the data.
To be fully honest, I don't think I know half of what that says.

Most cases essentially represent the data as a map of 2-dimensions: one input
dimensions $p$, and one output dimension

Essentially, the way I understand it is, it's designed to preserve the latent
structural elements within the map.

# %% [markdown]
# ## <font color='Green'> Some examples

# %% [markdown]
# To get everyone comfortable with maps (and with how the codebase implements them),
# let us consider

# %% [markdown]
# (1) Simple toy example
#
# Here is a relatively gentle first example:
#
# (2) Slightly more complex image example
#
# More complex image example? How would that differ from keysom
#
# (3) Simple keysom example

# %% [markdown]
# ## <font color='Green'> How are SOMs used in this library?

# %% [markdown]
# Continuing the previous simple example
#
# Two main aspects:
#
# (1) Key Profiles
#
#
#
# (2) Extracting latent characteristic data from those key profile
#
#
#
# (3) Application of keysom

# %% [markdown]
# ## <font color='Green'> Some interesting quirks of KeySOM.

# %% [markdown]
# (1) Compare asymmetric profile and symmetric profile
#
# (2) Compare dimensions
