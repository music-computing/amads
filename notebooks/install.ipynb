# %% [markdown]
# # AMADS Coding Notebooks
# ## Install
#
# ---
#
# **By (author/s):** Mark Gotham
#
# **For:** Attached to the
# [AMADS code library](https://github.com/music-computing/amads/) and
# ["Keeping Score" book](https://doi.org/10.5281/zenodo.14938027),
# but open to all.
#
# **Licence:** MIT.
#
# **Colour key:**
# - <font color='green'> Green is for a block of information.
# - <font color='purple'> Purple is for an exercise.
# - <font color='crimson'> Crimson is for the solution to the exercise above it.
#
# **Learning Objectives:** After completing this notebook, you will be able to ...
# - Install AMADS as a package via `pip`.
# - If needed, install an editable version from a local copy (advanced users).

# %% [markdown]
# ## <font color='green'> It Always Begins with Installation

# %% [markdown]
# Every package needs to be installed (one time) and imported (everytime you use it).
#
# Here is the import line:

# %%
import amads

# %% [markdown]
# If that ^^ works, you're done and can stop this notebook:
# simply `import` as needed in other notebooks.
#
# More likely, this is your first time with `AMADS` and so you need to install it first.
#
# As with every libary, you can install in many ways, including the following.

# %% [markdown]
# ### <font color='green'> Most users: install a version of the package from `pip`

# %% [markdown]
# Most users will want an official released version of AMADS.
#
# Options (one of):
# 1. Use the `pip` command here in this notebook: uncomment the cell below and run it one time,
# 2. Use the command line (same `pip` command),
# 3. Use graphical user interfaces like anaconda-navigator.

# %% [markdown]
# For all cases:

# %%
# pip install amads

# %% [markdown]
# You should now be able to `import amads` as above.

# %% [markdown]
# ### <font color='green'> Advanced Users: Install from a local version
#
# Some users may prefer to install from a local version.
# This is typically for advanced users who wish to make changes for their own purposes and/or to contribute to the code base.
# If this is not you and you are happy with the above, ignore the rest of this.
#
# For the local copy, head to GitHub to either:
# - download the zip (one snapshot)
# - clone the repo (full version history: https://github.com/music-computing/amads.git)
#
# This notebook is in `amads/notebooks` from there:

# %%
from pathlib import Path

# If you're in our notebooks folder this should work for a path, otherwise adapt as needed:
NOTEBOOK_DIR = Path.cwd()

# Head up one level to the top level of AMADS where a `pyproject.toml` file is located.
AMADS_TOP_LEVEL = NOTEBOOK_DIR.parent

# %%
# !python -m pip install -e "{AMADS_TOP_LEVEL}"

# %% [markdown]
# This will check you have `amads` and provide some information about it.

# %%
# !pip show amads

# %% [markdown]
# You should now be able to `import amads` as above.
# You may need to restart the kernel.
# In Jupyter:
# - Click the "Kernel" option in the toolbar above
# - Then click "Restart" from the dropdown menu

# %% [markdown]
# END OF NOTEBOOK
